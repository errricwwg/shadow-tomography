# %% [markdown]
# # Collecting Classical Shadows
#
# This notebook demonstrates how to collect classical shadow measurements from quantum states.
#
# ## Topics Covered
# - Random Pauli measurements
# - Weighted Pauli measurements
# - Clifford measurements
# - Shadow data collection from dense states
# - Shadow data collection from MPS
# - Measurement statistics and analysis

# %%
# Add the parent directory to Python path for development
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

# Import required libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
from shadowgpt import physics

# %%
# Out:
# + I
